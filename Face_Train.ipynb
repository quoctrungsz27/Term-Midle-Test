# %% [markdown]
# <a href="https://colab.research.google.com/github/quoctrungsz27/Term-Midle-Test/blob/main/Face_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from numpy import asarray,save
from sklearn.model_selection import train_test_split
from time import time
from keras.utils import load_img, img_to_array
from keras.utils  import to_categorical
from keras.models import Sequential, Model
from keras.layers import *
from keras.layers import LeakyReLU
from keras.optimizers import Adam
from keras.engine.training import optimizers
from keras.backend import categorical_crossentropy

# %%
folder = '/content/drive/MyDrive/Colab Notebooks/Face data/'

img_size = 100;
photos, labels = list(), list()
for file in listdir(folder) :
  output = 0.0
  if file.startswith('Dien'):
    output = 1.0
  if file.startswith('Hoi'):
    output = 2.0
  if file.startswith('Trung'):
    output = 3.0
  if file.startswith('quyen'):
    output = 4.0
  if file.startswith('Toan'):
    output = 5.0
  if file.startswith('Luan'):
    output = 6.0
  
  photo = load_img(folder + file, target_size = (img_size,img_size))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = np.array(labels)
print(photos.shape, labels.shape)
# save('/content/drive/MyDrive/anh/hoa/hoa_photos.npy',photos)
# save('/content/drive/MyDrive/anh/hoa/hoa_labels.npy',labels)
# Out:
# (359, 100, 100, 3) (359,)

# %%
photos = photos.astype('float32')/255.0

print(photos.shape)
# Out:
# (359, 100, 100, 3)

# %%
(trainX, testX, trainY, testY) = train_test_split(photos, labels, test_size=0.20, stratify=labels, random_state=10)

(trainX, valX, trainY, valY) = train_test_split(trainX, trainY, test_size=0.25, random_state=10)

print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
print(valX.shape)
print(valY.shape)
# Out:
# (215, 100, 100, 3)
# (215,)
# (72, 100, 100, 3)
# (72,)
# (72, 100, 100, 3)
# (72,)

# %%
image_test=5
hinh = trainX[image_test]
plt.imshow(hinh) 
plt.show()  
print('Hinh này là: ', trainY[image_test])
# Out:
# Hoa này là:  0.0

# %%
for i in range(25):  # 30 hình ảnh
  plt.subplot(5,5,i+1) # 6 cột , 5 hàng
  plt.tight_layout()
  plt.imshow(trainX[i], interpolation='none')
  plt.title('so:{}'.format(trainY[i]))
  plt.xticks([])
  plt.yticks([])

# %%
 #one hot enccoding giatri mau tung diem anh tu thap phan duoi dang 10 bit
trainY = to_categorical (trainY)
testY=to_categorical(testY)
valY=to_categorical(valY)

print(trainY.shape)
print(testY.shape)
print(valY.shape)
# Out:
# (215, 7)
# (72, 7)
# (72, 7)

# %%
batch_size=32
epochs=50
classes = 7

#Tạo 1 mạng có 28x28 input và 10 output
model = Sequential()

# 1 bộ VGG
model.add(Conv2D(32, kernel_size=(3,3), activation = 'linear', input_shape=(img_size,img_size,3),padding = 'same'))
model.add(LeakyReLU(alpha=0.1))  # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding='same'))


# Bộ 2 VGG
model.add(Conv2D(64,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))


# Bộ 3 VGG
model.add(Conv2D(128,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))

# Bộ 4 VGG
model.add(Conv2D(256,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))

# ANN Model
model.add(Flatten()) # Lấy kích thước trước rồi làm phẳng
model.add(Dense(512, activation = 'linear'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation = 'softmax'))     



model.compile(loss = categorical_crossentropy, optimizer = Adam() , metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 100, 100, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 50, 50, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 256)       295168
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 13, 13, 256)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 512)               0
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 6,815,047
# Trainable params: 6,815,047
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time()
train = model.fit(trainX, trainY, batch_size,epochs=epochs,verbose = 1, validation_data=(valX, valY))
print(time()-start)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 10s 127ms/step - loss: 1.6217 - accuracy: 0.5535 - val_loss: 0.7843 - val_accuracy: 0.8056
# Epoch 2/50
# 7/7 [==============================] - 0s 24ms/step - loss: 0.4402 - accuracy: 0.8140 - val_loss: 0.0921 - val_accuracy: 0.9861
# Epoch 3/50
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0983 - accuracy: 0.9535 - val_loss: 0.0230 - val_accuracy: 0.9861
# Epoch 4/50
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0442 - val_accuracy: 0.9861
# Epoch 5/50
# 7/7 [==============================] - 0s 23ms/step - loss: 1.2860e-05 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9861
# Epoch 6/50
# 7/7 [==============================] - 0s 23ms/step - loss: 1.3412e-06 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9861
# Epoch 7/50
# 7/7 [==============================] - 0s 24ms/step - loss: 8.0007e-07 - accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 0.9861
# Epoch 8/50
# 7/7 [==============================] - 0s 23ms/step - loss: 2.6661e-05 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9861
# Epoch 9/50
# 7/7 [==============================] - 0s 26ms/step - loss: 1.3840e-05 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9861
# Epoch 10/50
# 7/7 [==============================] - 0s 25ms/step - loss: 1.1211e-06 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9861
# Epoch 11/50
# 7/7 [==============================] - 0s 23ms/step - loss: 4.6796e-07 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9861
# Epoch 12/50
# 7/7 [==============================] - 0s 23ms/step - loss: 3.8646e-07 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9861
# Epoch 13/50
# 7/7 [==============================] - 0s 24ms/step - loss: 3.4543e-07 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9861
# Epoch 14/50
# 7/7 [==============================] - 0s 23ms/step - loss: 3.2824e-07 - accuracy: 1.0000 - val_loss: 0.0321 - val_accuracy: 0.9861
# Epoch 15/50
# 7/7 [==============================] - 0s 32ms/step - loss: 3.0939e-07 - accuracy: 1.0000 - val_loss: 0.0321 - val_accuracy: 0.9861
# Epoch 16/50
# 7/7 [==============================] - 0s 30ms/step - loss: 3.0218e-07 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9861
# Epoch 17/50
# 7/7 [==============================] - 0s 24ms/step - loss: 2.9386e-07 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9861
# Epoch 18/50
# 7/7 [==============================] - 0s 24ms/step - loss: 2.8444e-07 - accuracy: 1.0000 - val_loss: 0.0319 - val_accuracy: 0.9861
# Epoch 19/50
# 7/7 [==============================] - 0s 23ms/step - loss: 2.7723e-07 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 0.9861
# Epoch 20/50
# 7/7 [==============================] - 0s 23ms/step - loss: 2.7224e-07 - accuracy: 1.0000 - val_loss: 0.0316 - val_accuracy: 0.9861
# Epoch 21/50
# 7/7 [==============================] - 0s 25ms/step - loss: 2.6503e-07 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 0.9861
# Epoch 22/50
# 7/7 [==============================] - 0s 30ms/step - loss: 2.5727e-07 - accuracy: 1.0000 - val_loss: 0.0314 - val_accuracy: 0.9861
# Epoch 23/50
# 7/7 [==============================] - 0s 24ms/step - loss: 2.5172e-07 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9861
# Epoch 24/50
# 7/7 [==============================] - 0s 24ms/step - loss: 2.4507e-07 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 0.9861
# Epoch 25/50
# 7/7 [==============================] - 0s 23ms/step - loss: 2.3897e-07 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9861
# Epoch 26/50
# 7/7 [==============================] - 0s 31ms/step - loss: 2.3454e-07 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 0.9861
# Epoch 27/50
# 7/7 [==============================] - 0s 30ms/step - loss: 2.2844e-07 - accuracy: 1.0000 - val_loss: 0.0308 - val_accuracy: 0.9861
# Epoch 28/50
# 7/7 [==============================] - 0s 23ms/step - loss: 2.2400e-07 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9861
# Epoch 29/50
# 7/7 [==============================] - 0s 23ms/step - loss: 2.1901e-07 - accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 0.9861
# Epoch 30/50
# 7/7 [==============================] - 0s 23ms/step - loss: 2.1180e-07 - accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9861
# Epoch 31/50
# 7/7 [==============================] - 0s 24ms/step - loss: 2.0681e-07 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 0.9861
# Epoch 32/50
# 7/7 [==============================] - 0s 23ms/step - loss: 2.0182e-07 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9861
# Epoch 33/50
# 7/7 [==============================] - 0s 24ms/step - loss: 1.9739e-07 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9861
# Epoch 34/50
# 7/7 [==============================] - 0s 24ms/step - loss: 1.9295e-07 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9861
# Epoch 35/50
# 7/7 [==============================] - 0s 25ms/step - loss: 1.8907e-07 - accuracy: 1.0000 - val_loss: 0.0297 - val_accuracy: 0.9861
# Epoch 36/50
# 7/7 [==============================] - 0s 23ms/step - loss: 1.8519e-07 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9861
# Epoch 37/50
# 7/7 [==============================] - 0s 24ms/step - loss: 1.8020e-07 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9861
# Epoch 38/50
# 7/7 [==============================] - 0s 23ms/step - loss: 1.7632e-07 - accuracy: 1.0000 - val_loss: 0.0292 - val_accuracy: 0.9861
# Epoch 39/50
# 7/7 [==============================] - 0s 29ms/step - loss: 1.7244e-07 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9861
# Epoch 40/50
# 7/7 [==============================] - 0s 23ms/step - loss: 1.6856e-07 - accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 0.9861
# Epoch 41/50
# 7/7 [==============================] - 0s 31ms/step - loss: 1.6523e-07 - accuracy: 1.0000 - val_loss: 0.0288 - val_accuracy: 0.9861
# Epoch 42/50
# 7/7 [==============================] - 0s 22ms/step - loss: 1.6246e-07 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 0.9861
# Epoch 43/50
# 7/7 [==============================] - 0s 23ms/step - loss: 1.5913e-07 - accuracy: 1.0000 - val_loss: 0.0286 - val_accuracy: 0.9861
# Epoch 44/50
# 7/7 [==============================] - 0s 23ms/step - loss: 1.5580e-07 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9861
# Epoch 45/50
# 7/7 [==============================] - 0s 29ms/step - loss: 1.5303e-07 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9861
# Epoch 46/50
# 7/7 [==============================] - 0s 35ms/step - loss: 1.5026e-07 - accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 0.9861
# Epoch 47/50
# 7/7 [==============================] - 0s 36ms/step - loss: 1.4693e-07 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9861
# Epoch 48/50
# 7/7 [==============================] - 0s 35ms/step - loss: 1.4361e-07 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9861
# Epoch 49/50
# 7/7 [==============================] - 0s 32ms/step - loss: 1.4028e-07 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 0.9861
# Epoch 50/50
# 7/7 [==============================] - 0s 33ms/step - loss: 1.3917e-07 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 0.9861
# 21.18613624572754

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/Save model/Face Model/Face_model.h5')

# %%
#from keras.models import load_model
#model = load_model('/content/drive/MyDrive/Colab Notebooks/Money data/Money Model/Money_model.h5')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')

plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1.1])
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']
loss=train.history['loss']
val_loss=train.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim(0)
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.show()

# %%
name= {1:'Dien', 2:'Hoi',3:'Trung',4:'quyen',5:'Toan',6:'Luan'}  
#test
filePath = '/content/drive/MyDrive/Colab Notebooks/Face data/Hoi (45).jpg'
testImage = load_img(filePath, target_size=(img_size,img_size))
arrayImage = img_to_array(testImage).reshape(1,img_size,img_size,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Predicted:  Hoi

# %%
# Tạo một mảng các chỉ số ngẫu nhiên
random_indices = np.random.choice(len(testX), size=72, replace=False)

# Lấy ra 30 mẫu ngẫu nhiên từ tập dữ liệu testX và testY
random_testX = testX[random_indices]
random_testY = testY[random_indices]

# Dùng mô hình để dự đoán nhãn của các mẫu trong tập dữ liệu ngẫu nhiên
results = model.predict(random_testX)
predicted_labels = np.argmax(results, axis=1)

from sklearn.metrics import accuracy_score
# tính độ chính xác 
accuracy = accuracy_score(np.argmax(random_testY, axis=1), predicted_labels)
print("Accuracy:", accuracy*100,"%")
# Out:
# 3/3 [==============================] - 0s 7ms/step
# Accuracy: 100.0 %
