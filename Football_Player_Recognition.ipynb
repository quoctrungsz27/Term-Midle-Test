# %% [markdown]
# <a href="https://colab.research.google.com/github/quoctrungsz27/Term-Midle-Test/blob/main/Football_Player_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from numpy import asarray,save
from sklearn.model_selection import train_test_split
from time import time
from keras.utils import load_img, img_to_array
from keras.utils  import to_categorical
from keras.models import Sequential, Model
from keras.layers import *
from keras.layers import LeakyReLU
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.engine.training import optimizers
from keras.backend import categorical_crossentropy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder = '/content/drive/MyDrive/Colab Notebooks/Football Player Recognition/'

img_size = 100;
photos, labels = list(), list()
for file in listdir(folder) :
  output = 0.0
  if file.startswith('ibrahimovic'):
    output = 1.0
  if file.startswith('messi'):
    output = 2.0
  if file.startswith('pele'):
    output = 3.0
  if file.startswith('ronaldo'):
    output = 4.0
  if file.startswith('ronandinho'):
    output = 5.0
  
  photo = load_img(folder + file, target_size = (img_size,img_size))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = np.array(labels)
print(photos.shape, labels.shape)
# save('/content/drive/MyDrive/anh/hoa/hoa_photos.npy',photos)
# save('/content/drive/MyDrive/anh/hoa/hoa_labels.npy',labels)
# Out:
# (393, 100, 100, 3) (393,)

# %%
photos = photos.astype('float32')/255.0

print(photos.shape)
# Out:
# (393, 100, 100, 3)

# %%
(trainX, testX, trainY, testY) = train_test_split(photos, labels, test_size=0.20, stratify=labels, random_state=10)

(trainX, valX, trainY, valY) = train_test_split(trainX, trainY, test_size=0.25, random_state=10)

print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
print(valX.shape)
print(valY.shape)
# Out:
# (235, 100, 100, 3)
# (235,)
# (79, 100, 100, 3)
# (79,)
# (79, 100, 100, 3)
# (79,)

# %%
image_test=200
hinh = trainX[image_test]
plt.imshow(hinh) 
plt.show()  
print('Hình này là: ', trainY[image_test])
# Out:
# Hình này là:  2.0

# %%
for i in range(25):  # 30 hình ảnh
  plt.subplot(5,5,i+1) # 6 cột , 5 hàng
  plt.tight_layout()
  plt.imshow(trainX[i], interpolation='none')
  plt.title('so:{}'.format(trainY[i]))
  plt.xticks([])
  plt.yticks([])

# %%
 #one hot enccoding giatri mau tung diem anh tu thap phan duoi dang 10 bit
trainY = to_categorical (trainY)
testY=to_categorical(testY)
valY=to_categorical(valY)

print(trainY.shape)
print(testY.shape)
print(valY.shape)
# Out:
# (235, 6)
# (79, 6)
# (79, 6)

# %%
batch_size=32

classes = 6

#Tạo 1 mạng có 28x28 input và 10 output
model = Sequential()

# 1 bộ VGG
model.add(Conv2D(32, kernel_size=(3,3), activation = 'linear', input_shape=(img_size,img_size,3),padding = 'same'))
model.add(LeakyReLU(alpha=0.1))  # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding='same'))


# Bộ 2 VGG
model.add(Conv2D(64,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))


# Bộ 3 VGG
model.add(Conv2D(128,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))

# Bộ 4 VGG
model.add(Conv2D(256,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))

# ANN Model
model.add(Flatten()) # Lấy kích thước trước rồi làm phẳng
model.add(Dense(512, activation = 'linear'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation = 'softmax'))     



model.compile(loss = categorical_crossentropy, optimizer = Adam() , metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_44 (Conv2D)          (None, 100, 100, 32)      896
#
#  leaky_re_lu_57 (LeakyReLU)  (None, 100, 100, 32)      0
#
#  max_pooling2d_44 (MaxPoolin  (None, 50, 50, 32)       0
#  g2D)
#
#  conv2d_45 (Conv2D)          (None, 50, 50, 64)        18496
#
#  leaky_re_lu_58 (LeakyReLU)  (None, 50, 50, 64)        0
#
#  max_pooling2d_45 (MaxPoolin  (None, 25, 25, 64)       0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 25, 25, 128)       73856
#
#  leaky_re_lu_59 (LeakyReLU)  (None, 25, 25, 128)       0
#
#  max_pooling2d_46 (MaxPoolin  (None, 13, 13, 128)      0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 13, 13, 256)       295168
#
#  leaky_re_lu_60 (LeakyReLU)  (None, 13, 13, 256)       0
#
#  max_pooling2d_47 (MaxPoolin  (None, 7, 7, 256)        0
#  g2D)
#
#  flatten_13 (Flatten)        (None, 12544)             0
#
#  dense_26 (Dense)            (None, 512)               6423040
#
#  leaky_re_lu_61 (LeakyReLU)  (None, 512)               0
#
#  dense_27 (Dense)            (None, 6)                 3078
#
# =================================================================
# Total params: 6,814,534
# Trainable params: 6,814,534
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=50
start = time()
train = model.fit(trainX, trainY, batch_size,epochs=epochs,verbose = 1, validation_data=(valX, valY))
print(time()-start)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.9580 - accuracy: 0.2085 - val_loss: 1.6295 - val_accuracy: 0.2532
# Epoch 2/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.5872 - accuracy: 0.3021 - val_loss: 1.5363 - val_accuracy: 0.2785
# Epoch 3/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.4971 - accuracy: 0.3532 - val_loss: 1.3165 - val_accuracy: 0.4937
# Epoch 4/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.2967 - accuracy: 0.4681 - val_loss: 1.3268 - val_accuracy: 0.3797
# Epoch 5/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.1853 - accuracy: 0.5234 - val_loss: 1.2394 - val_accuracy: 0.4304
# Epoch 6/50
# 8/8 [==============================] - 12s 2s/step - loss: 1.0827 - accuracy: 0.5745 - val_loss: 1.1202 - val_accuracy: 0.5190
# Epoch 7/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.0323 - accuracy: 0.6383 - val_loss: 1.1731 - val_accuracy: 0.5570
# Epoch 8/50
# 8/8 [==============================] - 10s 1s/step - loss: 0.8748 - accuracy: 0.6851 - val_loss: 1.2889 - val_accuracy: 0.4937
# Epoch 9/50
# 8/8 [==============================] - 8s 1s/step - loss: 0.6698 - accuracy: 0.7872 - val_loss: 1.2508 - val_accuracy: 0.5443
# Epoch 10/50
# 8/8 [==============================] - 9s 1s/step - loss: 0.4820 - accuracy: 0.8383 - val_loss: 1.6511 - val_accuracy: 0.4430
# Epoch 11/50
# 8/8 [==============================] - 10s 1s/step - loss: 0.4031 - accuracy: 0.8553 - val_loss: 1.3469 - val_accuracy: 0.5443
# Epoch 12/50
# 8/8 [==============================] - 8s 951ms/step - loss: 0.2634 - accuracy: 0.9191 - val_loss: 2.4064 - val_accuracy: 0.5190
# Epoch 13/50
# 8/8 [==============================] - 10s 1s/step - loss: 0.3150 - accuracy: 0.8851 - val_loss: 1.6579 - val_accuracy: 0.5190
# Epoch 14/50
# 8/8 [==============================] - 10s 1s/step - loss: 0.2906 - accuracy: 0.8936 - val_loss: 1.6206 - val_accuracy: 0.5570
# Epoch 15/50
# 8/8 [==============================] - 8s 1s/step - loss: 0.1886 - accuracy: 0.9362 - val_loss: 2.2369 - val_accuracy: 0.4937
# Epoch 16/50
# 8/8 [==============================] - 10s 1s/step - loss: 0.1754 - accuracy: 0.9319 - val_loss: 1.4661 - val_accuracy: 0.5696
# Epoch 17/50
# 8/8 [==============================] - 9s 1s/step - loss: 0.1293 - accuracy: 0.9617 - val_loss: 1.9641 - val_accuracy: 0.5443
# Epoch 18/50
# 8/8 [==============================] - 9s 1s/step - loss: 0.1341 - accuracy: 0.9574 - val_loss: 2.1564 - val_accuracy: 0.4684
# Epoch 19/50
# 8/8 [==============================] - 10s 1s/step - loss: 0.0696 - accuracy: 0.9745 - val_loss: 2.0525 - val_accuracy: 0.6076
# Epoch 20/50
# 8/8 [==============================] - 8s 943ms/step - loss: 0.0294 - accuracy: 0.9915 - val_loss: 2.3140 - val_accuracy: 0.5823
# Epoch 21/50
# 8/8 [==============================] - 12s 1s/step - loss: 0.0146 - accuracy: 0.9957 - val_loss: 2.6204 - val_accuracy: 0.5063
# Epoch 22/50
# 8/8 [==============================] - 10s 1s/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 2.4441 - val_accuracy: 0.6076
# Epoch 23/50
# 8/8 [==============================] - 8s 1s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.2888 - val_accuracy: 0.5823
# Epoch 24/50
# 8/8 [==============================] - 10s 1s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.2948 - val_accuracy: 0.5949
# Epoch 25/50
# 8/8 [==============================] - 10s 1s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.4163 - val_accuracy: 0.5823
# Epoch 26/50
# 8/8 [==============================] - 8s 950ms/step - loss: 8.2781e-04 - accuracy: 1.0000 - val_loss: 2.5232 - val_accuracy: 0.5696
# Epoch 27/50
# 8/8 [==============================] - 10s 1s/step - loss: 5.8845e-04 - accuracy: 1.0000 - val_loss: 2.5756 - val_accuracy: 0.5570
# Epoch 28/50
# 8/8 [==============================] - 9s 1s/step - loss: 3.9121e-04 - accuracy: 1.0000 - val_loss: 2.6089 - val_accuracy: 0.5570
# Epoch 29/50
# 8/8 [==============================] - 8s 917ms/step - loss: 3.3063e-04 - accuracy: 1.0000 - val_loss: 2.6282 - val_accuracy: 0.5570
# Epoch 30/50
# 8/8 [==============================] - 10s 1s/step - loss: 2.8152e-04 - accuracy: 1.0000 - val_loss: 2.6433 - val_accuracy: 0.5570
# Epoch 31/50
# 8/8 [==============================] - 8s 1s/step - loss: 2.4910e-04 - accuracy: 1.0000 - val_loss: 2.6560 - val_accuracy: 0.5570
# Epoch 32/50
# 8/8 [==============================] - 10s 1s/step - loss: 2.2768e-04 - accuracy: 1.0000 - val_loss: 2.6680 - val_accuracy: 0.5696
# Epoch 33/50
# 8/8 [==============================] - 10s 1s/step - loss: 2.0695e-04 - accuracy: 1.0000 - val_loss: 2.6805 - val_accuracy: 0.5696
# Epoch 34/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.9129e-04 - accuracy: 1.0000 - val_loss: 2.6923 - val_accuracy: 0.5696
# Epoch 35/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.7957e-04 - accuracy: 1.0000 - val_loss: 2.7045 - val_accuracy: 0.5696
# Epoch 36/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.6741e-04 - accuracy: 1.0000 - val_loss: 2.7169 - val_accuracy: 0.5696
# Epoch 37/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.5842e-04 - accuracy: 1.0000 - val_loss: 2.7283 - val_accuracy: 0.5696
# Epoch 38/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.4985e-04 - accuracy: 1.0000 - val_loss: 2.7379 - val_accuracy: 0.5696
# Epoch 39/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.4260e-04 - accuracy: 1.0000 - val_loss: 2.7502 - val_accuracy: 0.5696
# Epoch 40/50
# 8/8 [==============================] - 8s 959ms/step - loss: 1.3366e-04 - accuracy: 1.0000 - val_loss: 2.7605 - val_accuracy: 0.5696
# Epoch 41/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.2791e-04 - accuracy: 1.0000 - val_loss: 2.7715 - val_accuracy: 0.5696
# Epoch 42/50
# 8/8 [==============================] - 8s 1s/step - loss: 1.2272e-04 - accuracy: 1.0000 - val_loss: 2.7817 - val_accuracy: 0.5696
# Epoch 43/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.1710e-04 - accuracy: 1.0000 - val_loss: 2.7917 - val_accuracy: 0.5696
# Epoch 44/50
# 8/8 [==============================] - 9s 1s/step - loss: 1.1202e-04 - accuracy: 1.0000 - val_loss: 2.8007 - val_accuracy: 0.5696
# Epoch 45/50
# 8/8 [==============================] - 8s 982ms/step - loss: 1.0772e-04 - accuracy: 1.0000 - val_loss: 2.8096 - val_accuracy: 0.5696
# Epoch 46/50
# 8/8 [==============================] - 10s 1s/step - loss: 1.0360e-04 - accuracy: 1.0000 - val_loss: 2.8175 - val_accuracy: 0.5696
# Epoch 47/50
# 8/8 [==============================] - 8s 958ms/step - loss: 9.9338e-05 - accuracy: 1.0000 - val_loss: 2.8253 - val_accuracy: 0.5696
# Epoch 48/50
# 8/8 [==============================] - 9s 1s/step - loss: 9.5990e-05 - accuracy: 1.0000 - val_loss: 2.8335 - val_accuracy: 0.5696
# Epoch 49/50
# 8/8 [==============================] - 10s 1s/step - loss: 9.2264e-05 - accuracy: 1.0000 - val_loss: 2.8428 - val_accuracy: 0.5696
# Epoch 50/50
# 8/8 [==============================] - 8s 952ms/step - loss: 8.9325e-05 - accuracy: 1.0000 - val_loss: 2.8524 - val_accuracy: 0.5696
# 502.6707739830017

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')

plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1.1])
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']
loss=train.history['loss']
val_loss=train.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim(0)
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.show()

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/Save model/Football_player_model.h5')

# %%
#from keras.models import load_model
#model = load_model('/content/drive/MyDrive/Fingerprint Recognition/Fingerprint.h5')

# %%
name= {1:'ibrahimovic', 2:'messi',3:'pele',4:'ronaldo',5:'ronandinho'}  
#test
filePath = '/content/drive/MyDrive/Colab Notebooks/Football Player Recognition/messi (23).jpg'
testImage = load_img(filePath, target_size=(img_size,img_size))
arrayImage = img_to_array(testImage).reshape(1,img_size,img_size,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# Predicted:  messi

# %%
# Tạo một mảng các chỉ số ngẫu nhiên
random_indices = np.random.choice(len(testX), size=70, replace=False)

# Lấy ra 30 mẫu ngẫu nhiên từ tập dữ liệu testX và testY
random_testX = testX[random_indices]
random_testY = testY[random_indices]

# Dùng mô hình để dự đoán nhãn của các mẫu trong tập dữ liệu ngẫu nhiên
results = model.predict(random_testX)
predicted_labels = np.argmax(results, axis=1)

from sklearn.metrics import accuracy_score
# tính độ chính xác 
accuracy = accuracy_score(np.argmax(random_testY, axis=1), predicted_labels)
print("Accuracy:", accuracy*100,"%")
# Out:
# 3/3 [==============================] - 1s 163ms/step
# Accuracy: 51.42857142857142 %
